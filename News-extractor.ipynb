# %%
# Importing the necessary packages
import requests
import json
import csv
import re


# Defining and opening a csv file to store the data
csvfile = open("News.csv", 'wt', newline='', encoding="utf-8")
writer = csv.writer(csvfile)


# Defining the headers inside the csv file
csvrow = []
csvrow.append("Time")
csvrow.append("Author")
csvrow.append("Title")
csvrow.append("News Content")
writer.writerow(csvrow)


# Extracting and storing data for keyword 'Canada'
url = ('https://newsapi.org/v2/everything?'
       'q=Canada&'
       'from=2019-11-01&'
       'pageSize=100&'
       'apiKey=79e642ae0adb407e8566eeb2e48210cf')

response = requests.get(url)

for i in range(0,100):
    
    csvrow = []
    csvrow.append(response.json()['articles'][i]['title'])
    csvrow.append(response.json()['articles'][i]['author'])
    csvrow.append(response.json()['articles'][i]['publishedAt'])
    csvrow.append(response.json()['articles'][i]['description'])
    writer.writerow(csvrow)

    
# Extracting and storing data for keyword 'University'    
url = ('https://newsapi.org/v2/everything?'
       'q=University&'
       'from=2019-11-01&'
       'pageSize=100&'
       'apiKey=79e642ae0adb407e8566eeb2e48210cf')

response = requests.get(url)

for i in range(0,100):
    
    csvrow = []
    csvrow.append(response.json()['articles'][i]['title'])
    csvrow.append(response.json()['articles'][i]['author'])
    csvrow.append(response.json()['articles'][i]['publishedAt'])
    csvrow.append(response.json()['articles'][i]['description'])
    writer.writerow(csvrow)

    
# Extracting and storing data for keyword 'Dalhousie University'
url = ('https://newsapi.org/v2/everything?'
       'q=Dalhousie-University&'
       'pageSize=100&'
       'apiKey=79e642ae0adb407e8566eeb2e48210cf')

response = requests.get(url)

for i in range(0,100):
    
    csvrow = []
    csvrow.append(response.json()['articles'][i]['title'])
    csvrow.append(response.json()['articles'][i]['author'])
    csvrow.append(response.json()['articles'][i]['publishedAt'])
    csvrow.append(response.json()['articles'][i]['description'])
    writer.writerow(csvrow)

    
# Extracting and storing data for keyword 'Halifax'
url = ('https://newsapi.org/v2/everything?'
       'q=Halifax&'
       'from=2019-11-01&'
       'pageSize=100&'
       'apiKey=79e642ae0adb407e8566eeb2e48210cf')

response = requests.get(url)

for i in range(0,100):
    
    csvrow = []
    csvrow.append(response.json()['articles'][i]['title'])
    csvrow.append(response.json()['articles'][i]['author'])
    csvrow.append(response.json()['articles'][i]['publishedAt'])
    csvrow.append(response.json()['articles'][i]['description'])
    writer.writerow(csvrow)

    
# Extracting and storing data for keyword 'Canada Education'
url = ('https://newsapi.org/v2/everything?'
       'q=Canada-Education&'
       'from=2019-11-01&'
       'pageSize=100&'
       'apiKey=79e642ae0adb407e8566eeb2e48210cf')

response = requests.get(url)

for i in range(0,100):
    
    csvrow = []
    csvrow.append(response.json()['articles'][i]['title'])
    csvrow.append(response.json()['articles'][i]['author'])
    csvrow.append(response.json()['articles'][i]['publishedAt'])
    csvrow.append(response.json()['articles'][i]['description'])
    writer.writerow(csvrow)

    
# Closing the csv file
csvfile.close()


# Indicator to know that extracting and storing is finished successfully
print("Done")
# Out:
# Done
